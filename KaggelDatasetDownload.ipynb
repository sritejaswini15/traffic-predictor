# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4a12c518-601a-4bb2-b0b3-d5aadbd4e502" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a12c518-601a-4bb2-b0b3-d5aadbd4e502">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d annsanababy/road-traffic-prediction-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/annsanababy/road-traffic-prediction-dataset
# License(s): unknown
# ...
#   0% 0.00/101k [00:00<?, ?B/s]
# 100% 101k/101k [00:00<00:00, 319MB/s]

# %%
# !unzip road-traffic-prediction-dataset.zip -d road_traffic_data
# Out:
# Archive:  road-traffic-prediction-dataset.zip
#   inflating: road_traffic_data/traffic-prediction-dataset.csv

# %%
# !ls road_traffic_data
# Out:
# traffic-prediction-dataset.csv

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/road_traffic_data/traffic-prediction-dataset.csv')

# Display the first few rows
df.head()
# Out:
#    Cross 1   Cross 2   Cross 3   Cross 4   Cross 5   Cross 6
# 0    105.0      48.0        30      62.0        31     110.0
# 1     97.0      41.0        32      55.0        42     103.0
# 2     76.0      47.0        44      58.0        40     100.0
# 3     98.0      40.0        39      59.0        43     104.0
# 4     87.0      41.0        47      49.0        35     112.0

# %%
df.info()      # shows column names, data types, and missing values
df.describe()  # shows basic statistics
df.shape       # gives (rows, columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16128 entries, 0 to 16127
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Cross 1   16128 non-null  float64
#  1    Cross 2  16128 non-null  float64
#  2    Cross 3  16128 non-null  int64
#  3    Cross 4  16128 non-null  float64
#  4    Cross 5  16128 non-null  int64
#  5    Cross 6  16128 non-null  float64
# dtypes: float64(4), int64(2)
# memory usage: 756.1 KB
# (16128, 6)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
#  17014780017159020801928975463144.jpg
# '23wh1a6641 (1)'
# '23WH1A6641 (1)'
# '23wh1a6641 (1).pdf'
# '23WH1A6641 adhaar.jpeg'
# '23wh1a6641 ass3.pdf'
# '23WH1A6641 Ass3.pdf'
#  23WH1A6641.bee.pdf
#  23wh1a6641_ds.pdf
# '23WH1A6641 left thumb.jpeg'
# '23WH1A6641 passport photo.jpeg'
#  23wh1a6641.pdf
#  23WH1A6641.pdf
# '23wh1a6641 .pdf'
#  23wh1a6641_Sania.zip
# '23wH1A6641 signature.jpg'
# '23WH1A6641 ssc memo - IQBAL SANIA.jpeg'
# '23WH1A6641 ssc memo.jpeg'
#  2a.gdoc
# '2b (1).gdoc'
#  2b.gdoc
# '3a (1).gdoc'
#  3a.gdoc
#  3b.gdoc
#  6641
# 'aapar id (1).pdf'
# 'aapar id.pdf'
# 'ABC_ID (1).mp4'
# 'Application Data.xlsx'
# 'aptpath_final[1].pptx'
# 'BlankPage (5).gdoc'
# 'BlankPage (6).gdoc'
# 'Colab Notebooks'
# 'Copy of payment (100).jpg'
# 'Copy of payment (101).jpg'
# 'Copy of payment (102).jpg'
# 'Copy of payment (103).jpg'
# 'Copy of payment (104).jpg'
# 'Copy of payment (105).jpg'
# 'Copy of payment (106).jpg'
# 'Copy of payment (107).jpg'
# 'Copy of payment (108).jpg'
# ...

# %%
from google.colab import files
import pandas as pd

# Upload the CSV manually
uploaded = files.upload()

# Read the uploaded file
df = pd.read_csv(next(iter(uploaded)))
print("✅ Data loaded successfully!")
df.head()
# Out:
#      <input type="file" id="files-48e16710-723d-4fe2-9ea2-767075794413" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48e16710-723d-4fe2-9ea2-767075794413">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16128 entries, 0 to 16127
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Cross 1   16128 non-null  float64
#  1    Cross 2  16128 non-null  float64
#  2    Cross 3  16128 non-null  int64
#  3    Cross 4  16128 non-null  float64
#  4    Cross 5  16128 non-null  int64
#  5    Cross 6  16128 non-null  float64
# dtypes: float64(4), int64(2)
# memory usage: 756.1 KB

# %%
df.describe()
# Out:
#             Cross 1       Cross 2       Cross 3       Cross 4       Cross 5  \
# count  16128.000000  16128.000000  16128.000000  16128.000000  16128.000000
# mean      95.806207     45.948444     41.510355     67.656870     36.232453
# std       87.586717     50.865051     41.849582     68.536141     37.372452
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        8.000000      2.000000      1.000000      0.000000      1.000000
# 50%       88.000000     29.000000     32.000000     45.000000     28.000000
# 75%      169.000000     77.000000     73.000000    124.000000     60.000000
# max      352.500000    302.000000    218.000000    312.000000    193.000000
#
#             Cross 6
# count  16128.000000
# mean      76.215185
# std       68.101792
# min        0.000000
# 25%        5.000000
# 50%       66.000000
# 75%      139.000000
# max      253.000000

# %%
df.isnull().sum()
# Out:
# Cross 1     0
#  Cross 2    0
#  Cross 3    0
#  Cross 4    0
#  Cross 5    0
#  Cross 6    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Traffic Data")
plt.show()
